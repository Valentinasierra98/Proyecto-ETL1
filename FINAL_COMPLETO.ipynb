# %%
import pandas as pd
from sqlalchemy import create_engine

# Configuración de la conexión con SQL Server usando SQLAlchemy
server = '127.0.0.1'
database = 'Actividad_ETL'
username = 'sa'
password = '12345678'

# Crear la URL de conexión
conn_str = f"mssql+pymssql://{username}:{password}@{server}/{database}"

# Crear el motor de conexión
engine = create_engine(conn_str)

# Ejecutar la consulta SQL y cargar los datos en un DataFrame
query = "SELECT * FROM dbo.tabla_etl_nueva1"
df = pd.read_sql(query, engine)

df.info()  # Tipos de datos, valores nulos

# Renombrar columnas: eliminar espacios y caracteres especiales
df.columns = df.columns.str.strip().str.replace(' ', '_').str.lower()
# Porcentaje de valores nulos por columna
print(df.isnull().sum().to_frame(name="Valores Nulos").assign(Porcentaje=lambda x: (x["Valores Nulos"] / len(df)) * 100))

numerical_columns = ["puntaje_global_icfes", "a_global", "a_lectura_critica", 
                     "a_matematicas", "a_sociales_y_ciudadanas", 
                     "a_ciencias_naturales", "a_ingles", "edad"]

# Identificadores (se mantienen como texto)
identifier_columns = ["codigo_estudiante", "registro_snp", "snp"]

# Aplicar conversiones
df[numerical_columns] = df[numerical_columns].astype("float64")
df[identifier_columns] = df[identifier_columns].astype("object")
df[df.select_dtypes(include=['object']).columns] = df.select_dtypes(include=['object']).astype("category")

# Verificación
df.info()

import pandas as pd

# Ajustar la visualización para mostrar todas las columnas
pd.set_option('display.max_columns', None)

# Ver las primeras 10 filas
print(df.head(10))

# Reemplazar únicamente los valores 0 en 'edad' con la mediana de la población
mediana_edad = df["edad"].median()
df.loc[df["edad"] == 0, "edad"] = mediana_edad

# Verificar que ya no haya valores nulos
print(df.isnull().sum())  # Debería mostrar solo ceros

import pandas as pd

# Listar las columnas del DataFrame
columnas_presentes = df.columns
print(columnas_presentes)

# Convertir las columnas a string para evitar problemas con categorías
coincidencias = (df["registro_snp"].astype(str) == df["snp"].astype(str)).sum()
diferencias = (df["registro_snp"].astype(str) != df["snp"].astype(str)).sum()

# Mostrar los resultados
print(f"Registros donde 'registro_snp' y 'snp' coinciden: {coincidencias}")
print(f"Registros donde 'registro_snp' y 'snp' son diferentes: {diferencias}")

import pandas as pd

# Convertir las columnas a tipo numérico para evitar problemas de comparación
df["puntaje_global_icfes"] = pd.to_numeric(df["puntaje_global_icfes"], errors="coerce")
df["a_global"] = pd.to_numeric(df["a_global"], errors="coerce")

# Verificar si las columnas son idénticas en todos los registros
if (df["puntaje_global_icfes"] == df["a_global"]).all():
    df.drop(columns=["a_global"], inplace=True)
    print("Las columnas son idénticas. 'a_global' ha sido eliminada.")
else:
    print("Las columnas tienen diferencias, no se ha eliminado ninguna.")


import pandas as pd

# Ajustar la visualización para mostrar todas las columnas
pd.set_option('display.max_columns', None)

# Ver las primeras 10 filas
print(df.head(10))

# Convertimos las columnas categóricas a string antes de reemplazar valores
df["estado_civil"] = df["estado_civil"].astype(str).replace(
    {"No registra": "No Registra", "Sin Registro": "No Registra", "Unión libre": "Unión Libre"}
).astype("category")

df["colegio_sector"] = df["colegio_sector"].astype(str).replace(
    {"NO REGISTRA": "No Registra", "SIN CLASIFICACION": "Sin Clasificación"}
).astype("category")

df["colegio_clasificacion"] = df["colegio_clasificacion"].astype(str).replace(
    {"NO REGISTRA": "No Registra", 
     "SIN CLASIFICACION": "Sin Clasificación",
     "SIN CLASIFICACIÓN": "Sin Clasificación"}  # Normaliza acentos
).astype("category")


import pandas as pd

# Ajustar la visualización para mostrar todas las columnas
pd.set_option('display.max_columns', None)

# Ver las primeras 10 filas
print(df.head(10))

df['codigo_estudiante'] = pd.to_numeric(df['codigo_estudiante'].astype(str), errors='coerce').astype('Int64')

print(df['codigo_estudiante'].head(10))  # Ver los primeros 10 valores print(df['codigo_estudiante'].isnull().sum())  # Contar valores nulos print(df.dtypes)  # Revisar el tipo de dato

# Convertir columnas de texto (object) a mayúsculas
for col in df.select_dtypes(include=['object']).columns:
    df[col] = df[col].str.upper()

# Convertir valores de las columnas categóricas a mayúsculas sin cambiar las categorías
columnas_categoricas = df.select_dtypes(include=['category']).columns
for col in columnas_categoricas:
    # Convertir los valores a mayúsculas sin cambiar las categorías
    df[col] = df[col].cat.codes.map(lambda x: df[col].cat.categories[x].upper())

# Verificar que los datos estén correctos
print(df.head(10))

#Carga de datos transformados a SQL
df.to_sql("TRANSFORMACION", engine, if_exists="replace", index=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11729 entries, 0 to 11728
# Data columns (total 40 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   codigo_estudiante              11729 non-null  float64
#  1   Registro_SNP                   11729 non-null  object
#  2   Periodo_Presentacion1          11729 non-null  object
#  3   Periodo_Presentacion           11729 non-null  object
#  4   Puntaje_Global_ICFES           11729 non-null  float64
#  5   A_Global                       11729 non-null  float64
#  6   A_Lectura_Critica              11729 non-null  float64
#  7   A_Matematicas                  11729 non-null  float64
#  8   A_Sociales_y_Ciudadanas        11729 non-null  float64
#  9   A_Ciencias_Naturales           11729 non-null  float64
#  10  A_Ingles                       11729 non-null  float64
#  11  A_Nivel_Ingles                 11729 non-null  object
#  12  Periodo_Academico              11727 non-null  object
#  13  Ano                            11727 non-null  float64
#  14  Genero                         11727 non-null  object
#  15  Edad                           11727 non-null  float64
#  16  Rango_Edad                     11727 non-null  object
#  17  Estado_Civil                   11727 non-null  object
#  18  Estrato_Economico              11727 non-null  float64
#  19  Municipio_Nacimiento           11727 non-null  object
#  20  Pais_Nacimiento                11727 non-null  object
#  21  Ciudad_Residencia              11727 non-null  object
#  22  SNIES                          11727 non-null  float64
#  23  Programa1                      11727 non-null  object
#  24  Programa                       11727 non-null  object
#  25  Cod_Programa                   11727 non-null  object
#  26  Plan                           11727 non-null  object
#  27  Tipo_Oferta                    11727 non-null  object
#  28  FACULTAD                       11727 non-null  object
#  29  Nivel_de_Formacion             11727 non-null  object
#  30  Modalidad_Programa             11727 non-null  object
#  31  Codigo_Dane                    10644 non-null  float64
#  32  Colegio                        11727 non-null  object
#  33  Departamento_Colegio           11727 non-null  object
#  34  Ciudad_Colegio                 11727 non-null  object
#  35  Colegio_Sector                 11727 non-null  object
#  36  Colegio_Clasificacion          11727 non-null  object
#  37  Reconocimiento_del_ministerio  11727 non-null  object
#  38  SNP                            11724 non-null  object
#  39  PERIODO_REGULAR                11727 non-null  object
# dtypes: float64(13), object(27)
# memory usage: 3.6+ MB
#                                Valores Nulos  Porcentaje
# codigo_estudiante                          0    0.000000
# registro_snp                               0    0.000000
# periodo_presentacion1                      0    0.000000
# periodo_presentacion                       0    0.000000
# puntaje_global_icfes                       0    0.000000
# a_global                                   0    0.000000
# a_lectura_critica                          0    0.000000
# a_matematicas                              0    0.000000
# a_sociales_y_ciudadanas                    0    0.000000
# a_ciencias_naturales                       0    0.000000
# a_ingles                                   0    0.000000
# a_nivel_ingles                             0    0.000000
# periodo_academico                          2    0.017052
# ano                                        2    0.017052
# genero                                     2    0.017052
# edad                                       2    0.017052
# rango_edad                                 2    0.017052
# estado_civil                               2    0.017052
# estrato_economico                          2    0.017052
# municipio_nacimiento                       2    0.017052
# pais_nacimiento                            2    0.017052
# ciudad_residencia                          2    0.017052
# snies                                      2    0.017052
# programa1                                  2    0.017052
# programa                                   2    0.017052
# cod_programa                               2    0.017052
# plan                                       2    0.017052
# tipo_oferta                                2    0.017052
# facultad                                   2    0.017052
# nivel_de_formacion                         2    0.017052
# modalidad_programa                         2    0.017052
# codigo_dane                             1085    9.250575
# colegio                                    2    0.017052
# departamento_colegio                       2    0.017052
# ciudad_colegio                             2    0.017052
# colegio_sector                             2    0.017052
# colegio_clasificacion                      2    0.017052
# reconocimiento_del_ministerio              2    0.017052
# snp                                        5    0.042629
# periodo_regular                            2    0.017052
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11729 entries, 0 to 11728
# Data columns (total 40 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   codigo_estudiante              11729 non-null  category
#  1   registro_snp                   11729 non-null  category
#  2   periodo_presentacion1          11729 non-null  category
#  3   periodo_presentacion           11729 non-null  category
#  4   puntaje_global_icfes           11729 non-null  float64
#  5   a_global                       11729 non-null  float64
#  6   a_lectura_critica              11729 non-null  float64
#  7   a_matematicas                  11729 non-null  float64
#  8   a_sociales_y_ciudadanas        11729 non-null  float64
#  9   a_ciencias_naturales           11729 non-null  float64
#  10  a_ingles                       11729 non-null  float64
#  11  a_nivel_ingles                 11729 non-null  category
#  12  periodo_academico              11727 non-null  category
#  13  ano                            11727 non-null  float64
#  14  genero                         11727 non-null  category
#  15  edad                           11727 non-null  float64
#  16  rango_edad                     11727 non-null  category
#  17  estado_civil                   11727 non-null  category
#  18  estrato_economico              11727 non-null  float64
#  19  municipio_nacimiento           11727 non-null  category
#  20  pais_nacimiento                11727 non-null  category
#  21  ciudad_residencia              11727 non-null  category
#  22  snies                          11727 non-null  float64
#  23  programa1                      11727 non-null  category
#  24  programa                       11727 non-null  category
#  25  cod_programa                   11727 non-null  category
#  26  plan                           11727 non-null  category
#  27  tipo_oferta                    11727 non-null  category
#  28  facultad                       11727 non-null  category
#  29  nivel_de_formacion             11727 non-null  category
#  30  modalidad_programa             11727 non-null  category
#  31  codigo_dane                    10644 non-null  float64
#  32  colegio                        11727 non-null  category
#  33  departamento_colegio           11727 non-null  category
#  34  ciudad_colegio                 11727 non-null  category
#  35  colegio_sector                 11727 non-null  category
#  36  colegio_clasificacion          11727 non-null  category
#  37  reconocimiento_del_ministerio  11727 non-null  category
#  38  snp                            11724 non-null  category
#  39  periodo_regular                11727 non-null  category
# dtypes: category(28), float64(12)
# memory usage: 2.6 MB
#   codigo_estudiante    registro_snp periodo_presentacion1  \
# 0         2195323.0  AC201910033951                  2019
# 1        22501672.0  AC202433990587                 20243
# 2        22500852.0  AC202433990587                 20243
# 3         2225642.0  AC202210102103                  2022
# 4        22500327.0  AC202431499839                 20243
# 5         2224980.0  AC202110026849                  2021
# 6         2248203.0  AC202410047035                  2024
# 7         2250908.0  AC202434004594                 20243
# 8         2215860.0  AC202110450791                  2021
# 9         2190665.0  AC201820454033                  2018
#
#   periodo_presentacion  puntaje_global_icfes    a_global  a_lectura_critica  \
# 0                20191            430.384615  430.384615               83.0
# 1                20243            425.000000  425.000000               81.0
# 2                20243            425.000000  425.000000               81.0
# 3                20221            428.461538  428.461538               81.0
# 4                20243            443.000000  443.000000               78.0
# 5                20211            411.923077  411.923077               78.0
# 6                20241            403.000000  403.000000               73.0
# 7                20243            403.000000  403.000000               71.0
# 8                20211            393.846154  393.846154               67.0
# 9                20182            380.000000  380.000000               66.0
#
#    a_matematicas  a_sociales_y_ciudadanas  a_ciencias_naturales  a_ingles  \
# 0           81.0                    100.0                  80.0      87.0
# 1           81.0                    100.0                  79.0      81.0
# 2           81.0                    100.0                  79.0      81.0
# 3           83.0                    100.0                  78.0      88.0
# 4          100.0                    100.0                  77.0      87.0
# 5           77.0                    100.0                  74.0      84.0
# 6           75.0                    100.0                  73.0      84.0
# 7           73.0                    100.0                  72.0     100.0
# 8           74.0                    100.0                  72.0      85.0
# 9           73.0                    100.0                  72.0      55.0
#
#   a_nivel_ingles periodo_academico     ano     genero  edad rango_edad  \
# 0           5.B+            2019-3  2019.0  Masculino  18.0    [15-19]
# 1           5.B+           2025-21  2025.0  Masculino  17.0    [15-19]
# 2           5.B+            2025-1  2025.0  Masculino  17.0    [15-19]
# 3           5.B+            2022-3  2022.0  Masculino  19.0    [15-19]
# 4           5.B+            2025-1  2025.0   Femenino  17.0    [15-19]
# 5           5.B+            2022-3  2022.0  Masculino  19.0    [15-19]
# 6           5.B+            2024-3  2024.0   Femenino  17.0    [15-19]
# 7           5.B+            2025-1  2025.0  Masculino  16.0    [15-19]
# 8           5.B+            2021-3  2021.0  Masculino  17.0    [15-19]
# 9           2.A1            2019-1  2019.0  Masculino  17.0    [15-19]
#
#   estado_civil  estrato_economico municipio_nacimiento pais_nacimiento  \
# 0      Soltero                5.0                 Cali        Colombia
# 1      Soltero                3.0                 CALI        COLOMBIA
# 2      Soltero                3.0                 CALI        COLOMBIA
# 3      Soltero                5.0                 Cali        Colombia
# 4      Soltero                2.0              POPAYAN        COLOMBIA
# 5      Soltero                4.0                 Cali        Colombia
# 6      Soltero                3.0                 Cali        Colombia
# 7      Soltero                4.0                 CALI        COLOMBIA
# 8      Soltero                4.0                 Cali        Colombia
# 9      Soltero                1.0             Pitalito        Colombia
#
#   ciudad_residencia     snies                                    programa1  \
# 0              Cali   55170.0  INGENIERIA ELECTRONICA Y TELECOMUNICACIONES
# 1              CALI  110364.0                       INGENIERIA INFORMATICA
# 2              CALI   20151.0                         INGENIERIA BIOMEDICA
# 3              Cali   20151.0                         INGENIERIA BIOMEDICA
# 4           POPAYAN   20115.0                       INGENIERIA INFORMATICA
# 5              Cali   20104.0                       INGENIERIA MECATRONICA
# 6              Cali  116011.0         NARRATIVAS Y ENTRETENIMIENTO DIGITAL
# 7              CALI   20100.0          MERCADEO Y NEGOCIOS INTERNACIONALES
# 8              Cali   20104.0                       INGENIERIA MECATRONICA
# 9              Cali   20095.0                        INGENIERIA INDUSTRIAL
#
#                                             programa cod_programa  plan  \
# 0  INGENIERIA ELECTRONICA Y TELECOMUNICACIONES-55170          EKT  EK06
# 1                      INGENIERIA INFORMATICA-110364          ISH  ISGB
# 2                         INGENIERIA BIOMEDICA-20151           BM  BM04
# 3                         INGENIERIA BIOMEDICA-20151           BM  BM04
# 4                       INGENIERIA INFORMATICA-20115           IS  IS06
# 5                       INGENIERIA MECATRONICA-20104           MK  MK06
# 6        NARRATIVAS Y ENTRETENIMIENTO DIGITAL-116011          NED  NED1
# 7          MERCADEO Y NEGOCIOS INTERNACIONALES-20100           MD  MD08
# 8                       INGENIERIA MECATRONICA-20104           MK  MK06
# 9                        INGENIERIA INDUSTRIAL-20095           ID  ID05
#
#   tipo_oferta                                  facultad nivel_de_formacion  \
# 0     REGULAR                                INGENIERIA      Universitario
# 1  DIGICAMPUS             INGENIERIA Y CIENCIAS BASICAS      Universitario
# 2     REGULAR             INGENIERIA Y CIENCIAS BASICAS      Universitario
# 3     REGULAR                                INGENIERIA      Universitario
# 4     REGULAR             INGENIERIA Y CIENCIAS BASICAS      Universitario
# 5     REGULAR                                INGENIERIA      Universitario
# 6     REGULAR  COMUNICACION SOCIAL, HUMANIDADES Y ARTES      Universitario
# 7     REGULAR                            ADMINISTRACION      Universitario
# 8     REGULAR                                INGENIERIA      Universitario
# 9     REGULAR                                INGENIERIA      Universitario
#
#                modalidad_programa   codigo_dane  \
# 0                      PRESENCIAL  3.760010e+11
# 1                         VIRTUAL  1.760010e+11
# 2                      PRESENCIAL  1.760010e+11
# 3                      PRESENCIAL  3.760010e+11
# 4                      PRESENCIAL  1.190010e+11
# 5                      PRESENCIAL  3.760010e+11
# 6  PRESENCIAL-VIRTUAL (COMBINADO)  3.760010e+11
# 7                      PRESENCIAL  1.760010e+11
# 8                      PRESENCIAL  3.760010e+11
# 9                      PRESENCIAL           NaN
#
#                                              colegio departamento_colegio  \
# 0                        COLEGIO BILINGÜE DIANA OESE      Valle Del Cauca
# 1  INSTITUCION EDUCATIVA TECNICA COMERCIAL LAS AM...      Valle Del Cauca
# 2  INSTITUCION EDUCATIVA TECNICA COMERCIAL LAS AM...      Valle Del Cauca
# 3                        COLEGIO BILINGÜE DIANA OESE      Valle Del Cauca
# 4  INSTITUCION EDUCATIVA NUESTRA SEÑORA DEL CARME...                Cauca
# 5                        COLEGIO BILINGÜE DIANA OESE      Valle Del Cauca
# 6                       COLEGIO LEONISTICO LA MERCED      Valle Del Cauca
# 7          INSTITUCION EDUCATIVA LICEO DEPARTAMENTAL      Valle Del Cauca
# 8  COLEGIO DEL SAGRADO CORAZON DE JESUS VALLE DEL...      Valle Del Cauca
# 9                                        NO REGISTRA                Huila
#
#   ciudad_colegio colegio_sector colegio_clasificacion  \
# 0           Cali     NO OFICIAL                    A+
# 1           CALI        OFICIAL                     B
# 2           CALI        OFICIAL                     B
# 3           Cali     NO OFICIAL                    A+
# 4        POPAYAN        OFICIAL                    A+
# 5           Cali     NO OFICIAL                    A+
# 6           Cali     NO OFICIAL                    A+
# 7           CALI        OFICIAL                    A+
# 8           Cali     NO OFICIAL                    A+
# 9         Timana    NO REGISTRA           NO REGISTRA
#
#   reconocimiento_del_ministerio             snp periodo_regular
# 0         Registro Alta Calidad  AC201910033951          2019-3
# 1         Registro Alta Calidad  AC202433990587          2025-1
# 2         Registro Alta Calidad  AC202433990587          2025-1
# 3         Registro Alta Calidad  AC202210102103          2022-3
# 4         Registro Alta Calidad  AC202431499839          2025-1
# 5         Registro Alta Calidad  AC202110026849          2022-3
# 6           Registro Calificado  AC202410047035          2024-3
# 7         Registro Alta Calidad  AC202434004594          2025-1
# 8         Registro Alta Calidad  AC202110450791          2021-3
# 9         Registro Alta Calidad  AC201820454033          2019-1
# codigo_estudiante                   0
# registro_snp                        0
# periodo_presentacion1               0
# periodo_presentacion                0
# puntaje_global_icfes                0
# a_global                            0
# a_lectura_critica                   0
# a_matematicas                       0
# a_sociales_y_ciudadanas             0
# a_ciencias_naturales                0
# a_ingles                            0
# a_nivel_ingles                      0
# periodo_academico                   2
# ano                                 2
# genero                              2
# edad                                2
# rango_edad                          2
# estado_civil                        2
# estrato_economico                   2
# municipio_nacimiento                2
# pais_nacimiento                     2
# ciudad_residencia                   2
# snies                               2
# programa1                           2
# programa                            2
# cod_programa                        2
# plan                                2
# tipo_oferta                         2
# facultad                            2
# nivel_de_formacion                  2
# modalidad_programa                  2
# codigo_dane                      1085
# colegio                             2
# departamento_colegio                2
# ciudad_colegio                      2
# colegio_sector                      2
# colegio_clasificacion               2
# reconocimiento_del_ministerio       2
# snp                                 5
# periodo_regular                     2
# dtype: int64
# Index(['codigo_estudiante', 'registro_snp', 'periodo_presentacion1',
#        'periodo_presentacion', 'puntaje_global_icfes', 'a_global',
#        'a_lectura_critica', 'a_matematicas', 'a_sociales_y_ciudadanas',
#        'a_ciencias_naturales', 'a_ingles', 'a_nivel_ingles',
#        'periodo_academico', 'ano', 'genero', 'edad', 'rango_edad',
#        'estado_civil', 'estrato_economico', 'municipio_nacimiento',
#        'pais_nacimiento', 'ciudad_residencia', 'snies', 'programa1',
#        'programa', 'cod_programa', 'plan', 'tipo_oferta', 'facultad',
#        'nivel_de_formacion', 'modalidad_programa', 'codigo_dane', 'colegio',
#        'departamento_colegio', 'ciudad_colegio', 'colegio_sector',
#        'colegio_clasificacion', 'reconocimiento_del_ministerio', 'snp',
#        'periodo_regular'],
#       dtype='object')
# Registros donde 'registro_snp' y 'snp' coinciden: 11619
# Registros donde 'registro_snp' y 'snp' son diferentes: 110
# Las columnas son idénticas. 'a_global' ha sido eliminada.
#   codigo_estudiante    registro_snp periodo_presentacion1  \
# 0         2195323.0  AC201910033951                  2019
# 1        22501672.0  AC202433990587                 20243
# 2        22500852.0  AC202433990587                 20243
# 3         2225642.0  AC202210102103                  2022
# 4        22500327.0  AC202431499839                 20243
# 5         2224980.0  AC202110026849                  2021
# 6         2248203.0  AC202410047035                  2024
# 7         2250908.0  AC202434004594                 20243
# 8         2215860.0  AC202110450791                  2021
# 9         2190665.0  AC201820454033                  2018
#
#   periodo_presentacion  puntaje_global_icfes  a_lectura_critica  \
# 0                20191            430.384615               83.0
# 1                20243            425.000000               81.0
# 2                20243            425.000000               81.0
# 3                20221            428.461538               81.0
# 4                20243            443.000000               78.0
# 5                20211            411.923077               78.0
# 6                20241            403.000000               73.0
# 7                20243            403.000000               71.0
# 8                20211            393.846154               67.0
# 9                20182            380.000000               66.0
#
#    a_matematicas  a_sociales_y_ciudadanas  a_ciencias_naturales  a_ingles  \
# 0           81.0                    100.0                  80.0      87.0
# 1           81.0                    100.0                  79.0      81.0
# 2           81.0                    100.0                  79.0      81.0
# 3           83.0                    100.0                  78.0      88.0
# 4          100.0                    100.0                  77.0      87.0
# 5           77.0                    100.0                  74.0      84.0
# 6           75.0                    100.0                  73.0      84.0
# 7           73.0                    100.0                  72.0     100.0
# 8           74.0                    100.0                  72.0      85.0
# 9           73.0                    100.0                  72.0      55.0
#
#   a_nivel_ingles periodo_academico     ano     genero  edad rango_edad  \
# 0           5.B+            2019-3  2019.0  Masculino  18.0    [15-19]
# 1           5.B+           2025-21  2025.0  Masculino  17.0    [15-19]
# 2           5.B+            2025-1  2025.0  Masculino  17.0    [15-19]
# 3           5.B+            2022-3  2022.0  Masculino  19.0    [15-19]
# 4           5.B+            2025-1  2025.0   Femenino  17.0    [15-19]
# 5           5.B+            2022-3  2022.0  Masculino  19.0    [15-19]
# 6           5.B+            2024-3  2024.0   Femenino  17.0    [15-19]
# 7           5.B+            2025-1  2025.0  Masculino  16.0    [15-19]
# 8           5.B+            2021-3  2021.0  Masculino  17.0    [15-19]
# 9           2.A1            2019-1  2019.0  Masculino  17.0    [15-19]
#
#   estado_civil  estrato_economico municipio_nacimiento pais_nacimiento  \
# 0      Soltero                5.0                 Cali        Colombia
# 1      Soltero                3.0                 CALI        COLOMBIA
# 2      Soltero                3.0                 CALI        COLOMBIA
# 3      Soltero                5.0                 Cali        Colombia
# 4      Soltero                2.0              POPAYAN        COLOMBIA
# 5      Soltero                4.0                 Cali        Colombia
# 6      Soltero                3.0                 Cali        Colombia
# 7      Soltero                4.0                 CALI        COLOMBIA
# 8      Soltero                4.0                 Cali        Colombia
# 9      Soltero                1.0             Pitalito        Colombia
#
#   ciudad_residencia     snies                                    programa1  \
# 0              Cali   55170.0  INGENIERIA ELECTRONICA Y TELECOMUNICACIONES
# 1              CALI  110364.0                       INGENIERIA INFORMATICA
# 2              CALI   20151.0                         INGENIERIA BIOMEDICA
# 3              Cali   20151.0                         INGENIERIA BIOMEDICA
# 4           POPAYAN   20115.0                       INGENIERIA INFORMATICA
# 5              Cali   20104.0                       INGENIERIA MECATRONICA
# 6              Cali  116011.0         NARRATIVAS Y ENTRETENIMIENTO DIGITAL
# 7              CALI   20100.0          MERCADEO Y NEGOCIOS INTERNACIONALES
# 8              Cali   20104.0                       INGENIERIA MECATRONICA
# 9              Cali   20095.0                        INGENIERIA INDUSTRIAL
#
#                                             programa cod_programa  plan  \
# 0  INGENIERIA ELECTRONICA Y TELECOMUNICACIONES-55170          EKT  EK06
# 1                      INGENIERIA INFORMATICA-110364          ISH  ISGB
# 2                         INGENIERIA BIOMEDICA-20151           BM  BM04
# 3                         INGENIERIA BIOMEDICA-20151           BM  BM04
# 4                       INGENIERIA INFORMATICA-20115           IS  IS06
# 5                       INGENIERIA MECATRONICA-20104           MK  MK06
# 6        NARRATIVAS Y ENTRETENIMIENTO DIGITAL-116011          NED  NED1
# 7          MERCADEO Y NEGOCIOS INTERNACIONALES-20100           MD  MD08
# 8                       INGENIERIA MECATRONICA-20104           MK  MK06
# 9                        INGENIERIA INDUSTRIAL-20095           ID  ID05
#
#   tipo_oferta                                  facultad nivel_de_formacion  \
# 0     REGULAR                                INGENIERIA      Universitario
# 1  DIGICAMPUS             INGENIERIA Y CIENCIAS BASICAS      Universitario
# 2     REGULAR             INGENIERIA Y CIENCIAS BASICAS      Universitario
# 3     REGULAR                                INGENIERIA      Universitario
# 4     REGULAR             INGENIERIA Y CIENCIAS BASICAS      Universitario
# 5     REGULAR                                INGENIERIA      Universitario
# 6     REGULAR  COMUNICACION SOCIAL, HUMANIDADES Y ARTES      Universitario
# 7     REGULAR                            ADMINISTRACION      Universitario
# 8     REGULAR                                INGENIERIA      Universitario
# 9     REGULAR                                INGENIERIA      Universitario
#
#                modalidad_programa   codigo_dane  \
# 0                      PRESENCIAL  3.760010e+11
# 1                         VIRTUAL  1.760010e+11
# 2                      PRESENCIAL  1.760010e+11
# 3                      PRESENCIAL  3.760010e+11
# 4                      PRESENCIAL  1.190010e+11
# 5                      PRESENCIAL  3.760010e+11
# 6  PRESENCIAL-VIRTUAL (COMBINADO)  3.760010e+11
# 7                      PRESENCIAL  1.760010e+11
# 8                      PRESENCIAL  3.760010e+11
# 9                      PRESENCIAL           NaN
#
#                                              colegio departamento_colegio  \
# 0                        COLEGIO BILINGÜE DIANA OESE      Valle Del Cauca
# 1  INSTITUCION EDUCATIVA TECNICA COMERCIAL LAS AM...      Valle Del Cauca
# 2  INSTITUCION EDUCATIVA TECNICA COMERCIAL LAS AM...      Valle Del Cauca
# 3                        COLEGIO BILINGÜE DIANA OESE      Valle Del Cauca
# 4  INSTITUCION EDUCATIVA NUESTRA SEÑORA DEL CARME...                Cauca
# 5                        COLEGIO BILINGÜE DIANA OESE      Valle Del Cauca
# 6                       COLEGIO LEONISTICO LA MERCED      Valle Del Cauca
# 7          INSTITUCION EDUCATIVA LICEO DEPARTAMENTAL      Valle Del Cauca
# 8  COLEGIO DEL SAGRADO CORAZON DE JESUS VALLE DEL...      Valle Del Cauca
# 9                                        NO REGISTRA                Huila
#
#   ciudad_colegio colegio_sector colegio_clasificacion  \
# 0           Cali     NO OFICIAL                    A+
# 1           CALI        OFICIAL                     B
# 2           CALI        OFICIAL                     B
# 3           Cali     NO OFICIAL                    A+
# 4        POPAYAN        OFICIAL                    A+
# 5           Cali     NO OFICIAL                    A+
# 6           Cali     NO OFICIAL                    A+
# 7           CALI        OFICIAL                    A+
# 8           Cali     NO OFICIAL                    A+
# 9         Timana    NO REGISTRA           NO REGISTRA
#
#   reconocimiento_del_ministerio             snp periodo_regular
# 0         Registro Alta Calidad  AC201910033951          2019-3
# 1         Registro Alta Calidad  AC202433990587          2025-1
# 2         Registro Alta Calidad  AC202433990587          2025-1
# 3         Registro Alta Calidad  AC202210102103          2022-3
# 4         Registro Alta Calidad  AC202431499839          2025-1
# 5         Registro Alta Calidad  AC202110026849          2022-3
# 6           Registro Calificado  AC202410047035          2024-3
# 7         Registro Alta Calidad  AC202434004594          2025-1
# 8         Registro Alta Calidad  AC202110450791          2021-3
# 9         Registro Alta Calidad  AC201820454033          2019-1
#   codigo_estudiante    registro_snp periodo_presentacion1  \
# 0         2195323.0  AC201910033951                  2019
# 1        22501672.0  AC202433990587                 20243
# 2        22500852.0  AC202433990587                 20243
# 3         2225642.0  AC202210102103                  2022
# 4        22500327.0  AC202431499839                 20243
# 5         2224980.0  AC202110026849                  2021
# 6         2248203.0  AC202410047035                  2024
# 7         2250908.0  AC202434004594                 20243
# 8         2215860.0  AC202110450791                  2021
# 9         2190665.0  AC201820454033                  2018
#
#   periodo_presentacion  puntaje_global_icfes  a_lectura_critica  \
# 0                20191            430.384615               83.0
# 1                20243            425.000000               81.0
# 2                20243            425.000000               81.0
# 3                20221            428.461538               81.0
# 4                20243            443.000000               78.0
# 5                20211            411.923077               78.0
# 6                20241            403.000000               73.0
# 7                20243            403.000000               71.0
# 8                20211            393.846154               67.0
# 9                20182            380.000000               66.0
#
#    a_matematicas  a_sociales_y_ciudadanas  a_ciencias_naturales  a_ingles  \
# 0           81.0                    100.0                  80.0      87.0
# 1           81.0                    100.0                  79.0      81.0
# 2           81.0                    100.0                  79.0      81.0
# 3           83.0                    100.0                  78.0      88.0
# 4          100.0                    100.0                  77.0      87.0
# 5           77.0                    100.0                  74.0      84.0
# 6           75.0                    100.0                  73.0      84.0
# 7           73.0                    100.0                  72.0     100.0
# 8           74.0                    100.0                  72.0      85.0
# 9           73.0                    100.0                  72.0      55.0
#
#   a_nivel_ingles periodo_academico     ano     genero  edad rango_edad  \
# 0           5.B+            2019-3  2019.0  Masculino  18.0    [15-19]
# 1           5.B+           2025-21  2025.0  Masculino  17.0    [15-19]
# 2           5.B+            2025-1  2025.0  Masculino  17.0    [15-19]
# 3           5.B+            2022-3  2022.0  Masculino  19.0    [15-19]
# 4           5.B+            2025-1  2025.0   Femenino  17.0    [15-19]
# 5           5.B+            2022-3  2022.0  Masculino  19.0    [15-19]
# 6           5.B+            2024-3  2024.0   Femenino  17.0    [15-19]
# 7           5.B+            2025-1  2025.0  Masculino  16.0    [15-19]
# 8           5.B+            2021-3  2021.0  Masculino  17.0    [15-19]
# 9           2.A1            2019-1  2019.0  Masculino  17.0    [15-19]
#
#   estado_civil  estrato_economico municipio_nacimiento pais_nacimiento  \
# 0      Soltero                5.0                 Cali        Colombia
# 1      Soltero                3.0                 CALI        COLOMBIA
# 2      Soltero                3.0                 CALI        COLOMBIA
# 3      Soltero                5.0                 Cali        Colombia
# 4      Soltero                2.0              POPAYAN        COLOMBIA
# 5      Soltero                4.0                 Cali        Colombia
# 6      Soltero                3.0                 Cali        Colombia
# 7      Soltero                4.0                 CALI        COLOMBIA
# 8      Soltero                4.0                 Cali        Colombia
# 9      Soltero                1.0             Pitalito        Colombia
#
#   ciudad_residencia     snies                                    programa1  \
# 0              Cali   55170.0  INGENIERIA ELECTRONICA Y TELECOMUNICACIONES
# 1              CALI  110364.0                       INGENIERIA INFORMATICA
# 2              CALI   20151.0                         INGENIERIA BIOMEDICA
# 3              Cali   20151.0                         INGENIERIA BIOMEDICA
# 4           POPAYAN   20115.0                       INGENIERIA INFORMATICA
# 5              Cali   20104.0                       INGENIERIA MECATRONICA
# 6              Cali  116011.0         NARRATIVAS Y ENTRETENIMIENTO DIGITAL
# 7              CALI   20100.0          MERCADEO Y NEGOCIOS INTERNACIONALES
# 8              Cali   20104.0                       INGENIERIA MECATRONICA
# 9              Cali   20095.0                        INGENIERIA INDUSTRIAL
#
#                                             programa cod_programa  plan  \
# 0  INGENIERIA ELECTRONICA Y TELECOMUNICACIONES-55170          EKT  EK06
# 1                      INGENIERIA INFORMATICA-110364          ISH  ISGB
# 2                         INGENIERIA BIOMEDICA-20151           BM  BM04
# 3                         INGENIERIA BIOMEDICA-20151           BM  BM04
# 4                       INGENIERIA INFORMATICA-20115           IS  IS06
# 5                       INGENIERIA MECATRONICA-20104           MK  MK06
# 6        NARRATIVAS Y ENTRETENIMIENTO DIGITAL-116011          NED  NED1
# 7          MERCADEO Y NEGOCIOS INTERNACIONALES-20100           MD  MD08
# 8                       INGENIERIA MECATRONICA-20104           MK  MK06
# 9                        INGENIERIA INDUSTRIAL-20095           ID  ID05
#
#   tipo_oferta                                  facultad nivel_de_formacion  \
# 0     REGULAR                                INGENIERIA      Universitario
# 1  DIGICAMPUS             INGENIERIA Y CIENCIAS BASICAS      Universitario
# 2     REGULAR             INGENIERIA Y CIENCIAS BASICAS      Universitario
# 3     REGULAR                                INGENIERIA      Universitario
# 4     REGULAR             INGENIERIA Y CIENCIAS BASICAS      Universitario
# 5     REGULAR                                INGENIERIA      Universitario
# 6     REGULAR  COMUNICACION SOCIAL, HUMANIDADES Y ARTES      Universitario
# 7     REGULAR                            ADMINISTRACION      Universitario
# 8     REGULAR                                INGENIERIA      Universitario
# 9     REGULAR                                INGENIERIA      Universitario
#
#                modalidad_programa   codigo_dane  \
# 0                      PRESENCIAL  3.760010e+11
# 1                         VIRTUAL  1.760010e+11
# 2                      PRESENCIAL  1.760010e+11
# 3                      PRESENCIAL  3.760010e+11
# 4                      PRESENCIAL  1.190010e+11
# 5                      PRESENCIAL  3.760010e+11
# 6  PRESENCIAL-VIRTUAL (COMBINADO)  3.760010e+11
# 7                      PRESENCIAL  1.760010e+11
# 8                      PRESENCIAL  3.760010e+11
# 9                      PRESENCIAL           NaN
#
#                                              colegio departamento_colegio  \
# 0                        COLEGIO BILINGÜE DIANA OESE      Valle Del Cauca
# 1  INSTITUCION EDUCATIVA TECNICA COMERCIAL LAS AM...      Valle Del Cauca
# 2  INSTITUCION EDUCATIVA TECNICA COMERCIAL LAS AM...      Valle Del Cauca
# 3                        COLEGIO BILINGÜE DIANA OESE      Valle Del Cauca
# 4  INSTITUCION EDUCATIVA NUESTRA SEÑORA DEL CARME...                Cauca
# 5                        COLEGIO BILINGÜE DIANA OESE      Valle Del Cauca
# 6                       COLEGIO LEONISTICO LA MERCED      Valle Del Cauca
# 7          INSTITUCION EDUCATIVA LICEO DEPARTAMENTAL      Valle Del Cauca
# 8  COLEGIO DEL SAGRADO CORAZON DE JESUS VALLE DEL...      Valle Del Cauca
# 9                                        NO REGISTRA                Huila
#
#   ciudad_colegio colegio_sector colegio_clasificacion  \
# 0           Cali     NO OFICIAL                    A+
# 1           CALI        OFICIAL                     B
# 2           CALI        OFICIAL                     B
# 3           Cali     NO OFICIAL                    A+
# 4        POPAYAN        OFICIAL                    A+
# 5           Cali     NO OFICIAL                    A+
# 6           Cali     NO OFICIAL                    A+
# 7           CALI        OFICIAL                    A+
# 8           Cali     NO OFICIAL                    A+
# 9         Timana    No Registra           No Registra
#
#   reconocimiento_del_ministerio             snp periodo_regular
# 0         Registro Alta Calidad  AC201910033951          2019-3
# 1         Registro Alta Calidad  AC202433990587          2025-1
# 2         Registro Alta Calidad  AC202433990587          2025-1
# 3         Registro Alta Calidad  AC202210102103          2022-3
# 4         Registro Alta Calidad  AC202431499839          2025-1
# 5         Registro Alta Calidad  AC202110026849          2022-3
# 6           Registro Calificado  AC202410047035          2024-3
# 7         Registro Alta Calidad  AC202434004594          2025-1
# 8         Registro Alta Calidad  AC202110450791          2021-3
# 9         Registro Alta Calidad  AC201820454033          2019-1
# 0     2195323
# 1    22501672
# 2    22500852
# 3     2225642
# 4    22500327
# 5     2224980
# 6     2248203
# 7     2250908
# 8     2215860
# 9     2190665
# Name: codigo_estudiante, dtype: Int64
#    codigo_estudiante    registro_snp periodo_presentacion1  \
# 0            2195323  AC201910033951                  2019
# 1           22501672  AC202433990587                 20243
# 2           22500852  AC202433990587                 20243
# 3            2225642  AC202210102103                  2022
# 4           22500327  AC202431499839                 20243
# 5            2224980  AC202110026849                  2021
# 6            2248203  AC202410047035                  2024
# 7            2250908  AC202434004594                 20243
# 8            2215860  AC202110450791                  2021
# 9            2190665  AC201820454033                  2018
#
#   periodo_presentacion  puntaje_global_icfes  a_lectura_critica  \
# 0                20191            430.384615               83.0
# 1                20243            425.000000               81.0
# 2                20243            425.000000               81.0
# 3                20221            428.461538               81.0
# 4                20243            443.000000               78.0
# 5                20211            411.923077               78.0
# 6                20241            403.000000               73.0
# 7                20243            403.000000               71.0
# 8                20211            393.846154               67.0
# 9                20182            380.000000               66.0
#
#    a_matematicas  a_sociales_y_ciudadanas  a_ciencias_naturales  a_ingles  \
# 0           81.0                    100.0                  80.0      87.0
# 1           81.0                    100.0                  79.0      81.0
# 2           81.0                    100.0                  79.0      81.0
# 3           83.0                    100.0                  78.0      88.0
# 4          100.0                    100.0                  77.0      87.0
# 5           77.0                    100.0                  74.0      84.0
# 6           75.0                    100.0                  73.0      84.0
# 7           73.0                    100.0                  72.0     100.0
# 8           74.0                    100.0                  72.0      85.0
# 9           73.0                    100.0                  72.0      55.0
#
#   a_nivel_ingles periodo_academico     ano     genero  edad rango_edad  \
# 0           5.B+            2019-3  2019.0  MASCULINO  18.0    [15-19]
# 1           5.B+           2025-21  2025.0  MASCULINO  17.0    [15-19]
# 2           5.B+            2025-1  2025.0  MASCULINO  17.0    [15-19]
# 3           5.B+            2022-3  2022.0  MASCULINO  19.0    [15-19]
# 4           5.B+            2025-1  2025.0   FEMENINO  17.0    [15-19]
# 5           5.B+            2022-3  2022.0  MASCULINO  19.0    [15-19]
# 6           5.B+            2024-3  2024.0   FEMENINO  17.0    [15-19]
# 7           5.B+            2025-1  2025.0  MASCULINO  16.0    [15-19]
# 8           5.B+            2021-3  2021.0  MASCULINO  17.0    [15-19]
# 9           2.A1            2019-1  2019.0  MASCULINO  17.0    [15-19]
#
#   estado_civil  estrato_economico municipio_nacimiento pais_nacimiento  \
# 0      SOLTERO                5.0                 CALI        COLOMBIA
# 1      SOLTERO                3.0                 CALI        COLOMBIA
# 2      SOLTERO                3.0                 CALI        COLOMBIA
# 3      SOLTERO                5.0                 CALI        COLOMBIA
# 4      SOLTERO                2.0              POPAYAN        COLOMBIA
# 5      SOLTERO                4.0                 CALI        COLOMBIA
# 6      SOLTERO                3.0                 CALI        COLOMBIA
# 7      SOLTERO                4.0                 CALI        COLOMBIA
# 8      SOLTERO                4.0                 CALI        COLOMBIA
# 9      SOLTERO                1.0             PITALITO        COLOMBIA
#
#   ciudad_residencia     snies                                    programa1  \
# 0              CALI   55170.0  INGENIERIA ELECTRONICA Y TELECOMUNICACIONES
# 1              CALI  110364.0                       INGENIERIA INFORMATICA
# 2              CALI   20151.0                         INGENIERIA BIOMEDICA
# 3              CALI   20151.0                         INGENIERIA BIOMEDICA
# 4           POPAYAN   20115.0                       INGENIERIA INFORMATICA
# 5              CALI   20104.0                       INGENIERIA MECATRONICA
# 6              CALI  116011.0         NARRATIVAS Y ENTRETENIMIENTO DIGITAL
# 7              CALI   20100.0          MERCADEO Y NEGOCIOS INTERNACIONALES
# 8              CALI   20104.0                       INGENIERIA MECATRONICA
# 9              CALI   20095.0                        INGENIERIA INDUSTRIAL
#
#                                             programa cod_programa  plan  \
# 0  INGENIERIA ELECTRONICA Y TELECOMUNICACIONES-55170          EKT  EK06
# 1                      INGENIERIA INFORMATICA-110364          ISH  ISGB
# 2                         INGENIERIA BIOMEDICA-20151           BM  BM04
# 3                         INGENIERIA BIOMEDICA-20151           BM  BM04
# 4                       INGENIERIA INFORMATICA-20115           IS  IS06
# 5                       INGENIERIA MECATRONICA-20104           MK  MK06
# 6        NARRATIVAS Y ENTRETENIMIENTO DIGITAL-116011          NED  NED1
# 7          MERCADEO Y NEGOCIOS INTERNACIONALES-20100           MD  MD08
# 8                       INGENIERIA MECATRONICA-20104           MK  MK06
# 9                        INGENIERIA INDUSTRIAL-20095           ID  ID05
#
#   tipo_oferta                                  facultad nivel_de_formacion  \
# 0     REGULAR                                INGENIERIA      UNIVERSITARIO
# 1  DIGICAMPUS             INGENIERIA Y CIENCIAS BASICAS      UNIVERSITARIO
# 2     REGULAR             INGENIERIA Y CIENCIAS BASICAS      UNIVERSITARIO
# 3     REGULAR                                INGENIERIA      UNIVERSITARIO
# 4     REGULAR             INGENIERIA Y CIENCIAS BASICAS      UNIVERSITARIO
# 5     REGULAR                                INGENIERIA      UNIVERSITARIO
# 6     REGULAR  COMUNICACION SOCIAL, HUMANIDADES Y ARTES      UNIVERSITARIO
# 7     REGULAR                            ADMINISTRACION      UNIVERSITARIO
# 8     REGULAR                                INGENIERIA      UNIVERSITARIO
# 9     REGULAR                                INGENIERIA      UNIVERSITARIO
#
#                modalidad_programa   codigo_dane  \
# 0                      PRESENCIAL  3.760010e+11
# 1                         VIRTUAL  1.760010e+11
# 2                      PRESENCIAL  1.760010e+11
# 3                      PRESENCIAL  3.760010e+11
# 4                      PRESENCIAL  1.190010e+11
# 5                      PRESENCIAL  3.760010e+11
# 6  PRESENCIAL-VIRTUAL (COMBINADO)  3.760010e+11
# 7                      PRESENCIAL  1.760010e+11
# 8                      PRESENCIAL  3.760010e+11
# 9                      PRESENCIAL           NaN
#
#                                              colegio departamento_colegio  \
# 0                        COLEGIO BILINGÜE DIANA OESE      VALLE DEL CAUCA
# 1  INSTITUCION EDUCATIVA TECNICA COMERCIAL LAS AM...      VALLE DEL CAUCA
# 2  INSTITUCION EDUCATIVA TECNICA COMERCIAL LAS AM...      VALLE DEL CAUCA
# 3                        COLEGIO BILINGÜE DIANA OESE      VALLE DEL CAUCA
# 4  INSTITUCION EDUCATIVA NUESTRA SEÑORA DEL CARME...                CAUCA
# 5                        COLEGIO BILINGÜE DIANA OESE      VALLE DEL CAUCA
# 6                       COLEGIO LEONISTICO LA MERCED      VALLE DEL CAUCA
# 7          INSTITUCION EDUCATIVA LICEO DEPARTAMENTAL      VALLE DEL CAUCA
# 8  COLEGIO DEL SAGRADO CORAZON DE JESUS VALLE DEL...      VALLE DEL CAUCA
# 9                                        NO REGISTRA                HUILA
#
#   ciudad_colegio colegio_sector colegio_clasificacion  \
# 0           CALI     NO OFICIAL                    A+
# 1           CALI        OFICIAL                     B
# 2           CALI        OFICIAL                     B
# 3           CALI     NO OFICIAL                    A+
# 4        POPAYAN        OFICIAL                    A+
# 5           CALI     NO OFICIAL                    A+
# 6           CALI     NO OFICIAL                    A+
# 7           CALI        OFICIAL                    A+
# 8           CALI     NO OFICIAL                    A+
# 9         TIMANA    NO REGISTRA           NO REGISTRA
#
#   reconocimiento_del_ministerio             snp periodo_regular
# 0         REGISTRO ALTA CALIDAD  AC201910033951          2019-3
# 1         REGISTRO ALTA CALIDAD  AC202433990587          2025-1
# 2         REGISTRO ALTA CALIDAD  AC202433990587          2025-1
# 3         REGISTRO ALTA CALIDAD  AC202210102103          2022-3
# 4         REGISTRO ALTA CALIDAD  AC202431499839          2025-1
# 5         REGISTRO ALTA CALIDAD  AC202110026849          2022-3
# 6           REGISTRO CALIFICADO  AC202410047035          2024-3
# 7         REGISTRO ALTA CALIDAD  AC202434004594          2025-1
# 8         REGISTRO ALTA CALIDAD  AC202110450791          2021-3
# 9         REGISTRO ALTA CALIDAD  AC201820454033          2019-1
# 16
